# %%
from Blackjack import load_decision_table
from RLDecisionTable import compare_dataframes
import pandas as pd

# %% [markdown]
# Loading and Comparing Decision Tables

# %%
dt_gt = pd.DataFrame(load_decision_table("../data/decisiontable_singles.csv")).T
dt_rl = pd.DataFrame(load_decision_table("../data/0.76_dt_rl.csv")).T
resultdf, equal, unequal = compare_dataframes(dt_gt,dt_rl)

# %% [markdown]
# Highlighted Differences in Decision Tables

# %%
resultdf
# Out:
#     2  3  4  5  6  7  8  9 10  A  J  K  Q
# 20
# 19
# 18
# 17
# 16                 x  x  x
# 15                 x  x  x
# 14                 x  x
# 13                 x
# 12  x  x           x
# 11  x  x  x  x  x  x  x  x  x  x  x  x  x
# 10  x  x  x  x  x  x  x  x
# 9   x  x  x  x  x
# 8   x  x  x  x  x
# 7   x  x  x
# 6   x  x
# 5   x  x

# %% [markdown]
# Decision Table (Ground Truth)

# %%
dt_gt
# Out:
#     2  3  4  5  6  7  8  9 10  A  J  K  Q
# 20  s  s  s  s  s  s  s  s  s  s  s  s  s
# 19  s  s  s  s  s  s  s  s  s  s  s  s  s
# 18  s  s  s  s  s  s  s  s  s  s  s  s  s
# 17  s  s  s  s  s  s  s  s  s  s  s  s  s
# 16  s  s  s  s  s  h  h  h  h  h  h  h  h
# 15  s  s  s  s  s  h  h  h  h  h  h  h  h
# 14  s  s  s  s  s  h  h  h  h  h  h  h  h
# 13  s  s  s  s  s  h  h  h  h  h  h  h  h
# 12  h  h  s  s  s  h  h  h  h  h  h  h  h
# 11  d  d  d  d  d  d  d  d  d  d  d  d  d
# 10  d  d  d  d  d  d  d  d  h  h  h  h  h
# 9   d  d  d  d  d  h  h  h  h  h  h  h  h
# 8   h  h  h  d  d  h  h  h  h  h  h  h  h
# 7   h  h  h  h  h  h  h  h  h  h  h  h  h
# 6   h  h  h  h  h  h  h  h  h  h  h  h  h
# 5   h  h  h  h  h  h  h  h  h  h  h  h  h

# %% [markdown]
# Decision Table learned by Reinforcement Learning

# %%
dt_rl
# Out:
#     2  3  4  5  6  7  8  9 10  A  J  K  Q
# 20  s  s  s  s  s  s  s  s  s  s  s  s  s
# 19  s  s  s  s  s  s  s  s  s  s  s  s  s
# 18  s  s  s  s  s  s  s  s  s  s  s  s  s
# 17  s  s  s  s  s  s  s  s  s  s  s  s  s
# 16  s  s  s  s  s  s  s  s  h  h  h  h  h
# 15  s  s  s  s  s  s  s  s  h  h  h  h  h
# 14  s  s  s  s  s  s  s  h  h  h  h  h  h
# 13  s  s  s  s  s  s  h  h  h  h  h  h  h
# 12  s  s  s  s  s  s  h  h  h  h  h  h  h
# 11  s  s  s  s  s  h  h  h  h  h  h  h  h
# 10  s  s  s  s  s  h  h  h  h  h  h  h  h
# 9   s  s  s  s  h  h  h  h  h  h  h  h  h
# 8   s  s  s  s  h  h  h  h  h  h  h  h  h
# 7   s  s  s  h  h  h  h  h  h  h  h  h  h
# 6   s  s  h  h  h  h  h  h  h  h  h  h  h
# 5   s  s  h  h  h  h  h  h  h  h  h  h  h
